# %% [markdown]
# # Učitavanje kategoriziranog .json file-a image dataseta:

# %%
import pandas as pd
import json

kategorije=pd.read_json('photo.json', lines='true')
kategorije
# Out:
#                    business_id  \
# 0       rcaPajgKOJC2vo_l3xa42A
# 1       Kn23LDd740SBVJ7mum0fwg
# 2       ZkGDCVKSdf8m76cnnalL-A
# 3       bF8gv7k_rwZtiDLP2ZB04w
# 4       50Anorn0DJXFhBr9a9_gHQ
# 5       5diHqpk_JSC4p8tIo4APow
# 6       qutQLFutEyHy440jpADnxA
# 7       57Ot-sRTzL925ipv-5SzTg
# 8       57Ot-sRTzL925ipv-5SzTg
# 9       UUGoM4q4i8rK2CBRS0xDAw
# 10      C74ViML3zx1akYVafLaiXQ
# 11      fepCIbejv-Kxs6SE6u-_uA
# 12      USleI8g1UVN9-9jm-b4uIg
# 13      USleI8g1UVN9-9jm-b4uIg
# 14      XNG9v1-DmScfwMShOmErcg
# 15      0lxyY2bwmpde2QHcnh8fZQ
# 16      -KIdCJnkt5N8rnnmWR5MQg
# 17      I6EDDi4-Eq_XlFghcDCUhw
# 18      JIl4gbnh_cORSjSrZgOjAQ
# 19      zU9w_xRlQSRIYXxGo-HSOA
# 20      AkpuhGyLAxhD_sLMQv3kOg
# 21      AkpuhGyLAxhD_sLMQv3kOg
# 22      HOmUXgWOl37CaLqmrsPwuw
# 23      AnXovUgUHJap3QaDRnjL1w
# 24      Trs4cEYdP6AX_KihTk9kWQ
# 25      XZbuPXdyA0ZtTu3AzqtQhg
# 26      -050d_XIor1NpCuWkbIVaQ
# 27      296PZdxSrtH08EUwCsOKMw
# 28      JEQaPs7jNT1M2os9lJDlUA
# ...

# %% [markdown]
# # Proučavanje dataseta:

# %%
kategorije.index
# Out:
# RangeIndex(start=0, stop=200000, step=1)

# %% [markdown]
# U datasetu ima 200 000 slika.

# %%
kategorije.columns
# Out:
# Index(['business_id', 'caption', 'label', 'photo_id'], dtype='object')

# %% [raw]
# Svaka je slika određena s 4 atributa:
# business_id: jedinstveni broj lokala/restorana
# caption: naslov/natpis
# label: pridružena kategorija
# photo_id: jedinstveni naziv slike

# %%
kategorije.groupby('label').size()
# Out:
# label
# drink       18121
# food       114874
# inside      52448
# menu         3023
# outside     11534
# dtype: int64

# %% [markdown]
# Slike u datasetu su razvrstane u 5 kategorija (drink, food, inside, menu, outside)

# %%
kategorije.groupby('business_id').size()
# Out:
# business_id
# --6MefnULPED_I942VcFNA     3
# --9e1ONYQuAa-CB_Rrw7Tw    74
# --DaPTJW3-tB1vP-PfdTEg     1
# --FBCX-N37CMYDfs790Bnw     1
# --KCl2FvVQpvjzmZSPyviA     2
# --Ni3oJ4VOqfOEu7Sj2Vzg     3
# --S62v0QgkqQaVUhFnNHrw     5
# --SrzpvFLwP_YFwB_Cetow    10
# --cZ6Hhc9F7VkKXxHMVZSQ     6
# --cjBEbXMI2obtaRHNSFrA     7
# --ujyvoQlwVoBgMYtADiLA     7
# -01XupAWZEXbdNbxNg5mEg     7
# -050d_XIor1NpCuWkbIVaQ     7
# -0CTrPQNiSyClxhdO4HSDQ     1
# -0DET7VdEQOJVJ_v6klEug    12
# -0NhdsDJsdarxyDPR523ZQ     3
# -0NrB58jqKqJfuUCDupcsw     4
# -0RRiWDtfnS16AKCtfvBZg     1
# -0RkJ_uIduNLWQrphbADRw    14
# -0T0jfPnuBRdpNTXpOQZcA     2
# -0WegMt6Cy966qlDKhu6jA     4
# -0mgn9dRi95otXd_h61LdA     2
# -0tgMGl7D9B10YjSN2ujLA     2
# -1UMR00eXtwaeh59pEiDjA    14
# -1VaIJza42Hjev6ukacCNg     3
# -1m9o3vGRA8IBPNvNqKLmA    29
# -1u4Q4U6OZ-CvqoxUh7gKg     2
# -1vfRrlnNnNJ5boOVghMPA     2
# -1xCh7Cocn6IwFzhELyohA     2
# -1xuC540Nycht_iWFeJ-dw    19
#                           ..
# ...

# %% [markdown]
# Kako business_id -ova ima znatno manje nego slika(30488), možemo zaključiti kako može postojati više fotografija s jednog mjesta/lokala

# %% [markdown]
# # Učitavanje nekoliko kategoriziranih slika:

# %% [markdown]
# Slika kategorije 'drink':

# %%
from IPython.display import Image
Image(filename='photos/TISF1w0dosCPWoxHwH63ww.jpg')

# %% [markdown]
# Slika kategorije 'outside':

# %%
from IPython.display import Image
Image(filename='photos/wxPgeZZypbmCWvzFKHhBFA.jpg')

# %% [markdown]
# Slika kategorije 'food':

# %%
from IPython.display import Image
Image(filename='photos/cfYWTTkg2ABYsC0XGFWXPQ.jpg')

# %% [markdown]
# Slika kategorije 'inside':

# %%
from IPython.display import Image
Image(filename='photos/1eDvPC4F8cGvuI2lGpIoEw.jpg')

# %% [markdown]
# #Slika kategorije 'menu':

# %%
from IPython.display import Image
Image(filename='photos/CFGAsffG9KDoeyp6ESWKNw.jpg')
